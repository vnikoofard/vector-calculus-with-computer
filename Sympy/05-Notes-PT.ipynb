# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Initial-imports" data-toc-modified-id="Initial-imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Initial imports</a></span></li><li><span><a href="#Geometria-de-Curvas-Espaciais" data-toc-modified-id="Geometria-de-Curvas-Espaciais-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Geometria de Curvas Espaciais</a></span><ul class="toc-item"><li><span><a href="#Curvas-paramétricas" data-toc-modified-id="Curvas-paramétricas-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Curvas paramétricas</a></span><ul class="toc-item"><li><span><a href="#Um-Exemplo:-Trajetoria-de-um-Projetil-em-2D" data-toc-modified-id="Um-Exemplo:-Trajetoria-de-um-Projetil-em-2D-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Um Exemplo: Trajetoria de um Projetil em 2D</a></span></li><li><span><a href="#Circulo" data-toc-modified-id="Circulo-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Circulo</a></span><ul class="toc-item"><li><span><a href="#Plot-do-circulo-usando-Sympy" data-toc-modified-id="Plot-do-circulo-usando-Sympy-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>Plot do circulo usando Sympy</a></span></li><li><span><a href="#Plot-do-circulo-usando-MatplotLib" data-toc-modified-id="Plot-do-circulo-usando-MatplotLib-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>Plot do circulo usando MatplotLib</a></span></li></ul></li><li><span><a href="#Helice" data-toc-modified-id="Helice-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Helice</a></span><ul class="toc-item"><li><span><a href="#Plot-da-helice-usando-Sympy" data-toc-modified-id="Plot-da-helice-usando-Sympy-2.1.3.1"><span class="toc-item-num">2.1.3.1&nbsp;&nbsp;</span>Plot da helice usando Sympy</a></span></li><li><span><a href="#Plot-da-helice-usando-Matplotlib" data-toc-modified-id="Plot-da-helice-usando-Matplotlib-2.1.3.2"><span class="toc-item-num">2.1.3.2&nbsp;&nbsp;</span>Plot da helice usando Matplotlib</a></span></li></ul></li><li><span><a href="#Segmento-de-reta" data-toc-modified-id="Segmento-de-reta-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Segmento de reta</a></span></li></ul></li><li><span><a href="#Vetor-de-Posição" data-toc-modified-id="Vetor-de-Posição-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Vetor de Posição</a></span></li><li><span><a href="#Velocidade-e-Aceleração" data-toc-modified-id="Velocidade-e-Aceleração-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Velocidade e Aceleração</a></span></li><li><span><a href="#Operações-Basicas" data-toc-modified-id="Operações-Basicas-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Operações Basicas</a></span><ul class="toc-item"><li><span><a href="#Produto-Escalar" data-toc-modified-id="Produto-Escalar-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Produto Escalar</a></span></li><li><span><a href="#Produto-Vetorial" data-toc-modified-id="Produto-Vetorial-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Produto Vetorial</a></span></li><li><span><a href="#Modulo" data-toc-modified-id="Modulo-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Modulo</a></span></li><li><span><a href="#Vetor-Unitario" data-toc-modified-id="Vetor-Unitario-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Vetor Unitario</a></span></li><li><span><a href="#Diferenciação" data-toc-modified-id="Diferenciação-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Diferenciação</a></span></li></ul></li><li><span><a href="#Velocidade-e-Aceleração" data-toc-modified-id="Velocidade-e-Aceleração-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Velocidade e Aceleração</a></span><ul class="toc-item"><li><span><a href="#Comprimento-de-Arco" data-toc-modified-id="Comprimento-de-Arco-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Comprimento de Arco</a></span></li></ul></li><li><span><a href="#Velocidade-e-Aceleração" data-toc-modified-id="Velocidade-e-Aceleração-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Velocidade e Aceleração</a></span></li><li><span><a href="#Reparametrização" data-toc-modified-id="Reparametrização-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Reparametrização</a></span></li></ul></li><li><span><a href="#Invariantes-Geometricas" data-toc-modified-id="Invariantes-Geometricas-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Invariantes Geometricas</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Parametrização-em-Relação-ao-Comprimento-de-Arco" data-toc-modified-id="Parametrização-em-Relação-ao-Comprimento-de-Arco-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Parametrização em Relação ao Comprimento de Arco</a></span></li></ul></li><li><span><a href="#Comprimento-de-Arco" data-toc-modified-id="Comprimento-de-Arco-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Comprimento de Arco</a></span><ul class="toc-item"><li><span><a href="#Parametrização-em-Relação-ao-Comprimento-de-Arco" data-toc-modified-id="Parametrização-em-Relação-ao-Comprimento-de-Arco-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Parametrização em Relação ao Comprimento de Arco</a></span></li></ul></li><li><span><a href="#Triedro-de-Frenet" data-toc-modified-id="Triedro-de-Frenet-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Triedro de Frenet</a></span></li><li><span><a href="#Curvatura-e-Torção" data-toc-modified-id="Curvatura-e-Torção-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Curvatura e Torção</a></span></li><li><span><a href="#Exemplos" data-toc-modified-id="Exemplos-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Exemplos</a></span><ul class="toc-item"><li><span><a href="#Astroide" data-toc-modified-id="Astroide-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Astroide</a></span></li><li><span><a href="#Cicloide" data-toc-modified-id="Cicloide-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Cicloide</a></span></li><li><span><a href="#Epiciclóide" data-toc-modified-id="Epiciclóide-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Epiciclóide</a></span></li><li><span><a href="#Epitrocóide" data-toc-modified-id="Epitrocóide-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Epitrocóide</a></span></li><li><span><a href="#Cubica-Retorcida" data-toc-modified-id="Cubica-Retorcida-3.4.5"><span class="toc-item-num">3.4.5&nbsp;&nbsp;</span>Cubica Retorcida</a></span></li></ul></li></ul></li><li><span><a href="#Planos-Tangentes" data-toc-modified-id="Planos-Tangentes-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Planos Tangentes</a></span><ul class="toc-item"><li><span><a href="#Definição" data-toc-modified-id="Definição-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Definição</a></span></li><li><span><a href="#Plotar-um-plano" data-toc-modified-id="Plotar-um-plano-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Plotar um plano</a></span><ul class="toc-item"><li><span><a href="#Plotar-um-plano-usando-Sympy" data-toc-modified-id="Plotar-um-plano-usando-Sympy-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Plotar um plano usando Sympy</a></span></li><li><span><a href="#Plotar-um-plano-usando-matplotlib" data-toc-modified-id="Plotar-um-plano-usando-matplotlib-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Plotar um plano usando matplotlib</a></span></li></ul></li><li><span><a href="#Usar-derivadas-parciais-para-achar-plano-tangente" data-toc-modified-id="Usar-derivadas-parciais-para-achar-plano-tangente-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Usar derivadas parciais para achar plano tangente</a></span></li></ul></li><li><span><a href="#Superficies-Parametrizadas" data-toc-modified-id="Superficies-Parametrizadas-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Superficies Parametrizadas</a></span></li><li><span><a href="#Vectorial-Fields" data-toc-modified-id="Vectorial-Fields-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Vectorial Fields</a></span></li><li><span><a href="#Differential-Operations" data-toc-modified-id="Differential-Operations-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Differential Operations</a></span></li><li><span><a href="#Line-Integral" data-toc-modified-id="Line-Integral-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Line Integral</a></span></li><li><span><a href="#Surface-integral" data-toc-modified-id="Surface-integral-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Surface integral</a></span></li></ul></div>

# %% [markdown]
# # Vector Calculus with Sympy

# %% [markdown]
# **For now, in all of the note, the Cartesian Coordinate System is assumed.**

# %% [markdown]
# ## Initial imports

# %%
import numpy as np
from sympy import *
from sympy.vector import *
from sympy.plotting.plot import plot3d, plot3d_parametric_line, plot3d_parametric_surface, plot_parametric
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
init_printing()

# %%
'''
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75

plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 10, 6
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 14

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.serif'] = "cm"
#plt.rcParams['text.latex.preamble'] = "\usepackage{subdepth}, \usepackage{type1cm}"
'''
# Out:
#   File "<ipython-input-3-9de6c731bc31>", line 19
#     '''
#       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 567-568: truncated \uXXXX escape

# %% [markdown]
# ## Geometria de Curvas Espaciais

# %% [markdown]
# Cada curva tem certas características geométricas chamadas invariantes. Esses invariantes
# são relacionados com as propriedades físicas de curva. Alguns destes invariantes são:
# * comprimento do arco
# * o numero das singularidades,
# * curvatura, que mede quanto a curva se dobra,
# * torção, que mede quanto a curva se torce.

# %% [markdown]
# ### Curvas paramétricas

# %% [markdown]
# Vamos conhecer as curvas paramétricas através de um exemplo. Um exemplo da curva é a
# trajetoria de um móvel em 2D. Vamos estudar esse exemplo passo a passo. A trajetoria é representada

# %% [markdown]
# $$
# \vec{r} (t) =\begin{cases}
# x(t)=0.2t^2 + 5t + 0.5
# \\y(t)=-t^2+10t+2
# \end{cases}
# $$

# %% [markdown]
# Para começar, temos que definir as nossas variaveis. Tem varias formas de fazer isso. O jeito mais pratico é

# %%
x,y,z,t,s,u,v, phi, theta = symbols('x y z t s u v phi theta',real=True)

# %% [markdown]
# Para definir uma curva parametrizada, primeiramente temos de definir um sistema de coordenadas. Para fazer isso usamos a classe *CoordSys3D* do modulo *sympy.vector*.

# %%
R = CoordSys3D('R')

# %% [markdown]
# Agora **R** é o nosso sistema de coordenada Carteseana que tem tres eixos $\hat{i}, \hat{j}$ and $\hat{k}$.

# %%
R.i, R.j,R.k
# Out:
# (i_R, j_R, k_R)

# %% [markdown]
# #### Um Exemplo: Trajetoria de um Projetil em 2D

# %% [markdown]
# Depois de estabelecer um sistema de coordenadas, conseguimos definir uma curva parametrizada. Essas curvas são funções vetoriais e tem a seguinte forma

# %% [markdown]
# $$\vec r(t) = x(t) \hat{i} + y(t) \hat{j} +z(t) \hat{k}.$$

# %% [markdown]
# Agora temos tudo que é necessario para definir a nossa curva. Adotamos a seguinte abordagem para implementar uma curva parametrizada

# %%
def trajectory(t): return (0.2*(t**2) + 5*t +0.5)*R.i \
    + (-t**2+10*t+2)*R.j

# %% [markdown]
# Nos podemos acessar aos componentes da nossa função vetorial.

# %%
trajectory(t).components
# Out:
# ⎧          2                      2           ⎫
# ⎨i_R: 0.2⋅t  + 5⋅t + 0.5, j_R: - t  + 10⋅t + 2⎬
# ⎩                                             ⎭

# %% [markdown]
# O resultado acima é um dicionario. Podemos pegar as funções de cada eixo (os valores da dicionario) usando

# %%
trajectory(t).components.values()
# Out:
# dict_values([0.2*t**2 + 5*t + 0.5, -t**2 + 10*t + 2])

# %% [markdown]
# E para ser mais util, no nosso caso, é bom transformar o objeto acima em um *tuple* ou *list*

# %%
tuple(trajectory(t).components.values())
# Out:
# ⎛     2                 2           ⎞
# ⎝0.2⋅t  + 5⋅t + 0.5, - t  + 10⋅t + 2⎠

# %% [markdown]
# Agora vamos calcular o deslocamento da particlu entre $t=3$ e $t=6$

# %%
r3 = trajectory(3);
r6 = trajectory(6);
deslocamento = r6 - r3;
print(f"A posição da particula \n no instante t=3 é {r3} e \n no instante t=6 é {r6}.\
\n Só o deslocamento fica {deslocamento}")
# Out:
# A posição da particula
#  no instante t=3 é 17.3000000000000*R.i + 23*R.j e
#  no instante t=6 é 37.7000000000000*R.i + 26*R.j.
#  Só o deslocamento fica 20.4000000000000*R.i + 3*R.j

# %% [markdown]
# Agora vamos fazer um plot dessa configuração. O Sympy tem funções internas para fazer plot. Essas funções são baseadas em Matplotlib, porem, são problematicas az vezes. Por isso é melhor usar o proprio Matplotlib para plotar. Como foi mencionado anteriormente, as expressões do Sympy são analiticos, contrario do resto do Python puro e Matplotlib. Por isso para poder plotar as expressões do Sympy usando Matplotlib temos que ter uma ponte entre esses pacotes. A funções *Lambdify* do Sympy faz essa conexão para a gente!

# %%
trajectory_components = tuple(trajectory(t).components.values())
f = lambdify(t,trajectory_components)

# %%
f(t)
# Out:
# ⎛     2                 2           ⎞
# ⎝0.2⋅t  + 5⋅t + 0.5, - t  + 10⋅t + 2⎠

# %% [markdown]
# Como se sabe o nome da variavel é irrelevante!

# %%
f(x)
# Out:
# ⎛     2                 2           ⎞
# ⎝0.2⋅x  + 5⋅x + 0.5, - x  + 10⋅x + 2⎠

# %% [markdown]
# Esse objeto *f* é uma função que aceita valores numericos e retorna os Arrays do Numpy

# %%
points = f(np.arange(0, 5, 0.1));
points
# Out:
# (array([ 0.5  ,  1.002,  1.508,  2.018,  2.532,  3.05 ,  3.572,  4.098,
#          4.628,  5.162,  5.7  ,  6.242,  6.788,  7.338,  7.892,  8.45 ,
#          9.012,  9.578, 10.148, 10.722, 11.3  , 11.882, 12.468, 13.058,
#         13.652, 14.25 , 14.852, 15.458, 16.068, 16.682, 17.3  , 17.922,
#         18.548, 19.178, 19.812, 20.45 , 21.092, 21.738, 22.388, 23.042,
#         23.7  , 24.362, 25.028, 25.698, 26.372, 27.05 , 27.732, 28.418,
#         29.108, 29.802]),
#  array([ 2.  ,  2.99,  3.96,  4.91,  5.84,  6.75,  7.64,  8.51,  9.36,
#         10.19, 11.  , 11.79, 12.56, 13.31, 14.04, 14.75, 15.44, 16.11,
#         16.76, 17.39, 18.  , 18.59, 19.16, 19.71, 20.24, 20.75, 21.24,
#         21.71, 22.16, 22.59, 23.  , 23.39, 23.76, 24.11, 24.44, 24.75,
#         25.04, 25.31, 25.56, 25.79, 26.  , 26.19, 26.36, 26.51, 26.64,
#         26.75, 26.84, 26.91, 26.96, 26.99]))

# %% [markdown]
# Agora só plotar os pontos acima usando Matplotlib

# %%
fig, ax = plt.subplots(ncols=1)
#ax.set_aspect('equal')
plt.plot(points[0],points[1])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Trajetoria de uma particula em 2D')
plt.show()

# %% [markdown]
# Para saber a posição do vetor de posição da particula nos instantes $t=3$ e $t=6$ podemos plotar setas

# %%
fig, ax = plt.subplots(ncols=1)
#ax.set_aspect('equal')
plt.plot(points[0],points[1])
plt.arrow(0,0,f(3)[0],f(3)[1],head_width=1, head_length=1,length_includes_head = True)
plt.arrow(0,0,f(6)[0],f(6)[1],head_width=1, head_length=1,length_includes_head = True)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Trajetoria de uma particula em 2D')
plt.grid()
plt.show()

# %% [markdown]
# Para ver mais pontos ao longo do eixo $x$ basta inserir um intervalo maior na função *f*

# %%
points1 = f(np.arange(0, 12, 0.1));

# %%
fig, ax = plt.subplots(ncols=1)
#ax.set_aspect('equal')
plt.plot(points1[0],points1[1])
plt.arrow(0,0,f(3)[0],f(3)[1],head_width=1, head_length=1,length_includes_head = True)
plt.arrow(0,0,f(6)[0],f(6)[1],head_width=1, head_length=1,length_includes_head = True)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Trajetoria de uma particula em 2D')
plt.grid()
plt.show()

# %% [markdown]
# Um detalhe que merece ser enfatizado. O projetil não começou o seu movimento do ponto $(0,0)$. Por isso para $t=0$ não temos $y=0$. Podemos interpretar que o projetil foi lançado em um palco acima do chão e fora do centro de sistema de coordenadas.
# Como já sabemos da fisica, em um movimento 2D com aceleração para cima, a particula sobe e depois começa a cair. Agora é interessante descobrir quando $(t=?)$ a particula vai chegar ao solo. Para fazer isso temos que resolver a equação $y(t)=0$

# %%
time = solve(f(t)[1],t);
time
# Out:
# [5 - 3⋅√3, 5 + 3⋅√3]

# %% [markdown]
# A primeira solução é negativa, então não é aceitavel.

# %%
N(time[0])
# Out:
# -0.196152422706632

# %% [markdown]
# Portanto a particula volta ao solo no tempo

# %%
print(f'A particula chega ao solo no instante t={N(time[1])}')
# Out:
# A particula chega ao solo no instante t=10.1961524227066

# %% [markdown]
# Graficamente temos

# %%
x_final,y_final = f(N(time[1]))[0].round(),f(N(time[1]))[1].round()

# %%
fig, ax = plt.subplots(ncols=1)
#ax.set_aspect('equal')
plt.plot(points1[0],points1[1])
plt.arrow(0,0,f(3)[0],f(3)[1],head_width=1, head_length=1,length_includes_head = True)
plt.arrow(0,0,f(6)[0],f(6)[1],head_width=1, head_length=1,length_includes_head = True)
plt.arrow(0,0,float(x_final),float(y_final),head_width=1, head_length=1,length_includes_head = True)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Trajetoria de uma particula em 2D')
plt.grid()
plt.show()

# %% [markdown]
# Um detalhe que merece ser enfatizado. O móvel não começou o seu movimento do ponto $(0,0)$. Por isso para $t=0$ não temos $y=0$ (verifique!). Podemos interpretar que o móvel foi lançado em um palco acima do chão e fora do centro de sistema de coordenadas.

# %% [markdown]
# #### Circulo

# %% [markdown]
# Como outro exemplo, um circulo de raio um pode ser definido como

# %% [markdown]
# $$\vec r(t) = cos(t) \hat{i} + sin(t) \hat{j}$$

# %%
def circle(t): return cos(t)*R.i + sin(t)*R.j

# %%
circle(t)
# Out:
# (cos(t))*R.i + (sin(t))*R.j

# %% [markdown]
# ##### Plot do circulo usando Sympy

# %% [markdown]
# Como já foi mencionaod o Sympy tem uma função interna para plotar as curvas parametricas. Essa função fica no modulo *Sympy.plotting.plot* que foi importada no inicio do notebook. Essa função não reconhece o formato vetorial das nossas curvas e temos que extrair os componentes da curva e passar como tuple para ela.

# %%
circle_components = tuple(circle(t).components.values())

# %%
plot_parametric(*circle_components,(t,0,2*pi))
# Out:
# /home/vahid/miniconda3/lib/python3.7/site-packages/sympy/plotting/plot.py:1065: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax[i].spines['left'].set_smart_bounds(True)
# /home/vahid/miniconda3/lib/python3.7/site-packages/sympy/plotting/plot.py:1066: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax[i].spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# No momento que eu estava preparando essa nota devido a uma mudança no Matplotlib a função acima não estava funcionando.

# %% [markdown]
# Para automatizar o processo acima podemos definir a seguinte função. Lembrando que o modulo * plot_parametric * esteja importado.

# %%
def Plot_Parametric_Curve(curve, a):
    
    '''
    curve: must be in the notaion of sympy.vector
    a (tuple): (parameter, start, finish) 
    '''
    curve_components = tuple(curve.components.values())
    
    
    plot = plot_parametric(*curve_components, a)
    #ax = plot._backend.ax
    #fig = plt.figure()
    #ax = fig.add_subplot(111)
    #ax[0].set_aspect('equal')
    plt.show()
    
    pass

# %%
Plot_Parametric_Curve(circle(t),(t,0,2*pi))

# %% [markdown]
# ##### Plot do circulo usando MatplotLib

# %% [markdown]
# Para plotar o circulo vamos seguir os mesmos passos anteriores

# %%
cir = lambdify(t,circle_components)
points = cir(np.arange(0, 7, 0.1));

fig, ax = plt.subplots(ncols=1)

plt.plot(points[0],points[1])

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Circle')
plt.grid()
plt.show()

# %% [markdown]
# Oops! Aqui temos um problema! Os eixos não são iguais e o resultado do plot é uma elipse. Para forçar o Matplotlib de plotar os eixos igualmente podemos usar o seguinte comando

# %%
circle_components = tuple(circle(t).components.values())
cir = lambdify(t,circle_components)
points = cir(np.arange(0, 7, 0.1));
fig, ax = plt.subplots(ncols=1)
ax.set_aspect('equal')
plt.plot(points[0],points[1])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Circle')
plt.grid()
plt.show()

# %% [markdown]
# <span style="color:red"> **EXERCICIO** outra curva para metrizada em 2D é o astroide, $$\cos(t)^3$$</span>

# %% [markdown]
# #### Helice

# %% [markdown]
# Em 3D, para a helice $\vec r(t) = cos(t) \hat{i} + sin(t) \hat{j} + t \hat{k}$ é definida

# %%
def helix(t): return cos(t)*R.i + sin(t)*R.j + t*R.k

# %%
helix(t)
# Out:
# (cos(t))*R.i + (sin(t))*R.j + t*R.k

# %% [markdown]
# De novo, podemos acessar aos components de cada eixo usando *components* attribute.

# %%
helix(t).components
# Out:
# {i_R: cos(t), j_R: sin(t), k_R: t}

# %% [markdown]
# A projeção da helice ao longo do eixo $x$ é

# %%
helix(t).components[R.i]
# Out:
# cos(t)

# %% [markdown]
# ##### Plot da helice usando Sympy

# %% [markdown]
# Agora vamos traçar essa curva (helice). Verifique se o módulo *plot3d_parametric_line* seja importado. Com o formato que definimos nossa curva, não podemos a inserir diretamente na função definida para o módulo de plotagem. Dê uma olhada na ajuda de *plot3d_parametric_line*. Mas não fique nervoso! Nós podemos resolver isso. Primeiro, precisamos extrair os componentes e depois passá-los para o módulo de plotagem.

# %%
curve_components = tuple(helix(t).components.values())

# %% [markdown]
# Agora podemos passar o tuple acima para o módulo *plot3d_parametric_line*. Observe a descompactação do tuple usando `* ´

# %%
plot3d_parametric_line(*curve_components, (t,0,10*pi))
plt.show()

# %% [markdown]
# Podemos facilitar a tarefa definindo uma função simples que automatiza o procedimento acima. A função abaixo recebe uma curva parametrizada, semelhante à nossa notação, e o nome do parametro da curva e o intervalo do gráfico

# %%
def Plot3d_Parametric_Curve(curve, a):
    '''
    curve: must be in the notaion of sympy.vector
    a (tuple): (parameter, start, finish) 
    '''
    curve_components = tuple(curve.components.values())
    
    plot3d_parametric_line(*curve_components, a)
    plt.show()
    
    
    pass

# %%
Plot3d_Parametric_Curve(helix(t),(t,0,10*pi))

# %% [markdown]
# ##### Plot da helice usando Matplotlib

# %% [markdown]
# Para plotar usando Matplotlib seguimos uma aborgadem semelhante a anterior. Com essa diferença que agora a plotagem será em 3D e por isso tem alguns comandos diferentes

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.gca(projection='3d')

helix_components = tuple(helix(t).components.values())
helice = lambdify(t,helix_components)

points = helice(np.arange(0, 70, 0.1));

plt.plot(points[0],points[1],points[2])

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Helix')
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# <span style="color:red"> **EXERCICIO** Uma curva parametrizada em 2D é o cicloide, $$(t - \sin(t))\hat{i} +(1-\cos(t))\hat j .$$ Plote essa curva</span>

# %% [markdown]
# <span style="color:red"> **EXERCICIO** Uma curva parametrizada conhecida em 3D é o astroide, $$\cos(t)^3\hat{i} +\sin(t)^3\hat j + cos(2t) \hat k .$$ Plote essa curva</span>

# %% [markdown]
# #### Segmento de reta

# %% [markdown]
# Na disciplina Geometria Analítica, a gente aprendeu como construir as equações paramétricas de um segmento de reta que conecta dois pontos $P(x_1,y_1,z_1)$ e $Q(x_2,y_2,z_2)$. Para fazer isso temos que achar o vetor diretor. Depois usando esse vetor diretor e um dos pontos podemos construir as equações parametricas na seguinte forma
# $$
# \begin{cases}
# x(t) = a t +x_1
# \\ y(t) = b t + y_1 \qquad 0\leqslant t \leqslant 1
# \\ z(t) = c t +z_1
# \end{cases}
# $$
# onde $a, b$ e $c$ são componentes do vetor diretor da reta dado por
# $$
# \vec{v} = <a,b,c> = <x_2-x_1,y_2-y_1,.z_2-z_1,>
# $$

# %% [markdown]
# ### Vetor de Posição

# %% [markdown]
# Como já sabemos, uma curva é feita de infinitos pontos. Ao substituir um valor pelo parâmetro da curva, podemos encontrar o ponto associado a esse parâmetro. Por exemplo

# %%
helix(pi)
# Out:
# (-1)*R.i + pi*R.k

# %%
circle(pi)
# Out:
# (-1)*R.i

# %% [markdown]
# Uma curva parametrizada, como foi descutido anteriormente, pode ser imaginada como uma trajetória de uma partícula. Essa partícula possui uma posição vetorial que conecta sua posição no espaço à origem de um sistema de coordenadas. Se o parâmetro da curva for o tempo, variando o parâmetro, obtemos diferentes posições da partícula durante seu movimento.

# %% [markdown]
# <span style="color:red"> **EXERCICIO:** Usando Matplotlib, defina uma função chamada de Plot_Position_Vector de tal forma que como entrada pega uma tres objetos: uma curva 2D, um tuple que consista de (parametro, ponto inicial,ponto final) e o numero de vetores de posição da curva. O resultado para um circulo deve ser igual a figura abaixo. </span>

# %%
Plot_Position_Vector(circle(t),(t,0,2*pi), 35)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-136427c4b855> in <module>
# ----> 1 Plot_Position_Vector(circle(t),(t,0,2*pi), 35)
#
# NameError: name 'Plot_Position_Vector' is not defined

# %% [markdown]
# EXERCICIO: Usando Matplotlib, defina uma função chamada de Ploted_Position_Vector de tal forma que como entrada pega uma tres objetos: uma curva 3D, um tuple que consista de (parametro, ponto inicial, ponto final) e o numero de vetores de posição da curva. O resultado para uma helice deve ser igual ao resultado da função abaixo. Notem que ainda o Matplotlib não tem um modulo para plotar uma seta em 3D. Para fazer isso eu me inspirei em uma resposta em StackOverFlow [Putting arrowheads on vectors in matplotlib's 3d plot](https://stackoverflow.com/questions/22867620/putting-arrowheads-on-vectors-in-matplotlibs-3d-plot)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d

class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

# %% [markdown]
# A função abaixa foi adatada da respota [Putting together plots of Matplotlib and Sympy](https://stackoverflow.com/questions/60325325/putting-together-plots-of-matplotlib-and-sympy).

# %%
def move_sympyplot_to_axes(p, ax):
    backend = p.backend(p)
    backend.ax = ax
    # Fix for > sympy v1.5
    backend._process_series(backend.parent._series, ax, backend.parent)
    backend.ax.spines['right'].set_color('none')
    backend.ax.spines['bottom'].set_position('zero')
    backend.ax.spines['top'].set_color('none')
    plt.close(backend.fig)

# %% [markdown]
# Usando a classe acima para as curvas parametrizadas em 3D, temos

# %%
def Plot3d_Position_Vector(g, a, *arg):
    '''
    This function takes a 3D curve and draw some of its positional vectors.
    geometry: 3D parametric curve or surface.
    
    a: (Tulpe with 3 elements)(parameter, start, stop)
    
    arg: (Tulpe with 3 elements) in the case of surface this argument is necessary(second parameter, start, stop) 
    '''
    from sympy.plotting.plot import plot3d_parametric_line , plot3d_parametric_surface
    from mpl_toolkits.mplot3d import Axes3D
    
    geometry_components = tuple(g.components.values())
    
    
    #here we check to ensure that the free parameter of curve is the same as a[0]
    parameters = set()
    for component in geometry_components:
        # in the below the 'if statement' check if the component of curve is a sympy object. 
        if isinstance(component,tuple(core.all_classes)):
            parameters.update(component.free_symbols)
            
    
    #Deciding if the geometry is a curve or surface        
    if len(parameters)== 1:
        assert a[0]==list(parameters)[0], "Error: The parameter of curve must be the same as first element of second argument"
        plot_geometry = plot3d_parametric_line(*geometry_components, a, show = False)
    
    if len(parameters)== 2:
        b = arg[0] #in the case of surface is a second parameter and its domain
        plot_geometry = plot3d_parametric_surface(*geometry_components, a, arg[0], show = False)
    
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    
    if len(parameters) == 2:
        number1 = np.random.randint(a[1], a[2], 20)
        number2 = np.random.randint(b[1], b[2], 20)
        dx = [geometry_components[0].subs(a[0], i).subs(b[0],j) for i in number1 for j in number2]
        dy = [geometry_components[1].subs(a[0], i).subs(b[0],j) for i in number1 for j in number2]
        dz = [geometry_components[2].subs(a[0], i).subs(b[0],j) for i in number1 for j in number2]
    
    if len(parameters) == 1:
        numbers = np.random.randint(a[1], a[2], 20)
        dx = [geometry_components[0].subs(a[0], i) for i in numbers]
        dy = [geometry_components[1].subs(a[0], i) for i in numbers]
        dz = [geometry_components[2].subs(a[0], i) for i in numbers]
    
       
    for i in range(len(dx)):
        a = Arrow3D([0,float(dx[i])],[0,float(dy[i])],[0,float(dz[i])], 
                    mutation_scale=20, lw=2, arrowstyle="-|>", color="black")
        ax.add_artist(a)
        
    move_sympyplot_to_axes(plot_geometry, ax)
    plt.draw()
    plt.show()
    #return len(parameters)

# %% [markdown]
# As an example

# %%
Plot3d_Position_Vector(helix(t),(t,0,10*pi))

# %% [markdown]
# **Obviamente**, dá para ver que essa plotagem usando Sympy não é facil!

# %% [markdown]
# ### Velocidade e Aceleração

# %% [markdown]
# Se consideramos uma curva como a trajetoria de uma partícula, podemos chamar $\vec r (t)$ como o vetor de posição. Então a derivada deste vetor será o vetor de velocidade, $\vec v (t) = \vec{r^\prime}(t)$ e a segunda derivada será a aceleração, $\vec a (t) = \vec{v^\prime}(t)=\vec{t^{\prime\prime}}(t)$. A rapidez é definido como o modulo (magnitude) do vetor de velocidade, $v (t) = |\vec v (t)|$. <br/>
# Para calcular a velocidade de uma partícula que está se movimentando ao longo da hélice acima vamos fazer o seguinte procedimento

# %% [markdown]
# ### Operações Basicas

# %% [markdown]
# #### Produto Escalar

# %% [markdown]
# Aqui temos uma pergunta: como é o produto escalar entre duas  funções vetoriais? O Sympy já tem uma função interna para isso

# %%
x1 = Function('x1');x2 = Function('x2');y1 = Function('y1');
y2 = Function('y2');z1 = Function('z1');z2 = Function('z2')

def curve1(t): return x1(t)*R.i + y1(t)*R.j + z1(t)*R.k 
def curve2(t): return x2(t)*R.i + y2(t)*R.j + z2(t)*R.k

# %%
curve1(t).dot(curve2(t))
# Out:
# x₁(t)⋅x₂(t) + y₁(t)⋅y₂(t) + z₁(t)⋅z₂(t)

# %% [markdown]
# Vamos verificar alguns produtos conhecidos. O produto escalar entre os vetores de base $\hat j$ e $\hat j$ é

# %%
R.j.dot(R.j)
# Out:
# 1

# %% [markdown]
# O produto escalar entre os vetores de base $\hat i$ e $\hat j$ é

# %%
R.i.dot(R.j)
# Out:
# 0

# %% [markdown]
# #### Produto Vetorial

# %% [markdown]
# Afunção que faz o produto vetorial entre dois vetores tambem é predefinida

# %%
curve1(t).cross(curve2(t))
# Out:
# (y1(t)*z2(t) - y2(t)*z1(t))*R.i + (-x1(t)*z2(t) + x2(t)*z1(t))*R.j + (x1(t)*y2(t) - x2(t)*y1(t))*R.k

# %% [markdown]
# Só para testar vamos conferir alguns resultados conhecidos

# %%
curve1(t) ^ curve2(t)
# Out:
# (y1(t)*z2(t) - y2(t)*z1(t))*R.i + (-x1(t)*z2(t) + x2(t)*z1(t))*R.j + (x1(t)*y2(t) - x2(t)*y1(t))*R.k

# %%
R.i ^ R.j
# Out:
# R.k

# %%
R.i ^ R.i
# Out:
# 0

# %% [markdown]
# #### Modulo

# %% [markdown]
# Para encontrar a norma (módulo, magnitude) de um vetor definimos a seguinte função

# %%
def Norm(v):
    return simplify(sqrt(v.dot(v)))

# %% [markdown]
# Checando a função

# %%
Norm(curve1(t))
# Out:
#    __________________________
#   ╱   2        2        2
# ╲╱  x₁ (t) + y₁ (t) + z₁ (t)

# %% [markdown]
# De fato, existe uma função interna no Sympy que calcula a norma de um vetor

# %%
curve1(t).magnitude()
# Out:
#    __________________________
#   ╱   2        2        2
# ╲╱  x₁ (t) + y₁ (t) + z₁ (t)

# %% [markdown]
# #### Vetor Unitario

# %% [markdown]
# Para transformar um vetor em um vetor unitario (de modulo um)

# %%
def Unit_Vector(curve):
    return curve/Norm(curve)

# %%
Unit_Vector(curve1(t))
# Out:
# (x1(t)/sqrt(x1(t)**2 + y1(t)**2 + z1(t)**2))*R.i + (y1(t)/sqrt(x1(t)**2 + y1(t)**2 + z1(t)**2))*R.j + (z1(t)/sqrt(x1(t)**2 + y1(t)**2 + z1(t)**2))*R.k

# %% [markdown]
# Usando a função interna de *normalize* obtemos o mesmo resultado.

# %%
curve1(t).normalize()
# Out:
# (x1(t)/sqrt(x1(t)**2 + y1(t)**2 + z1(t)**2))*R.i + (y1(t)/sqrt(x1(t)**2 + y1(t)**2 + z1(t)**2))*R.j + (z1(t)/sqrt(x1(t)**2 + y1(t)**2 + z1(t)**2))*R.k

# %% [markdown]
# #### Diferenciação

# %% [markdown]
# Para a derivada de uma função vetorial temos a seguinte função

# %%
curve1(t).diff(t)
# Out:
# (Derivative(x1(t), t))*R.i + (Derivative(y1(t), t))*R.j + (Derivative(z1(t), t))*R.k

# %%
helix(t).diff(t)
# Out:
# (-sin(t))*R.i + (cos(t))*R.j + R.k

# %% [markdown]
# Se a função vetorial possui apenas uma variável (apenas curvas), não há necessidade de inseri-la explicitamente em *diff()*

# %%
helix(t).diff()
# Out:
# (-sin(t))*R.i + (cos(t))*R.j + R.k

# %% [markdown]
# ### Velocidade e Aceleração

# %% [markdown]
# Se consideramos uma curva como a trajetoria de uma partícula, podemos chamar $\vec r (t)$ como o vetor de posição. Então a derivada deste vetor será o vetor de velocidade, $\vec v (t) = \vec{r^\prime}(t)$ e a segunda derivada será a aceleração, $\vec a (t) = \vec{v^\prime}(t)=\vec{t^{\prime\prime}}(t)$. A rapidez é definido como o modulo (magnitude) do vetor de velocidade, $v (t) = |\vec v (t)|$. <br/>
# Para calcular a velocidade de uma partícula que está se movimentando ao longo da hélice acima vamos fazer o seguinte procedimento

# %% [markdown]
# #### Comprimento de Arco

# %% [markdown]
# Para encontrar o comprimento de uma curva entre dois pontos, $t \in [a,b]$ definimos a seguinte função

# %%
def Arc_Length(curve, a:Tuple): 
    return integrate(Norm(curve.diff()),a)

# %%
Arc_Length(helix(t),(t,0,pi))
# Out:
# √2⋅π

# %% [markdown]
# Calculando o valor numérico da expressão acima

# %%
N(Arc_Length(helix(t),(t,0,pi)))
# Out:
# 4.44288293815837

# %% [markdown]
# Calculando a circumferencia de um circulo com raio 3.

# %%
Arc_Length(3*circle(t),(t,0,2*pi))
# Out:
# 6⋅π

# %% [markdown]
# <span style="color:red"> **Exercício:** Use a função interna *magnitude()* para calcular o comprimento de uma curva </span>

# %% [markdown]
# ### Velocidade e Aceleração

# %% [markdown]
# Se consideramos uma curva como a trajetoria de uma partícula, podemos chamar $\vec r (t)$ como o vetor de posição. Então a derivada deste vetor será o vetor de velocidade, $\vec v (t) = \vec{r^\prime}(t)$ e a segunda derivada será a aceleração, $\vec a (t) = \vec{v^\prime}(t)=\vec{t^{\prime\prime}}(t)$. A rapidez é definido como o modulo (magnitude) do vetor de velocidade, $v (t) = |\vec v (t)|$. <br/>
# Para calcular a velocidade de uma partícula que está se movimentando ao longo da hélice acima vamos fazer o seguinte procedimento

# %%
# Só para relembrar
helix(t)
# Out:
# (cos(t))*R.i + (sin(t))*R.j + t*R.k

# %%
velocity_helix = helix(t).diff();
velocity_helix
# Out:
# (-sin(t))*R.i + (cos(t))*R.j + R.k

# %%
acceleration_helix = velocity_helix.diff();
acceleration_helix
# Out:
# (-cos(t))*R.i + (-sin(t))*R.j

# %% [markdown]
# Prestam atenção que os objetos *acceleration_helix* e *velocity_helix* não são funções e por isso não tem como os utilizar para achar a velocidade e aceleração da particula em um instante de tempo especifico.

# %%
acceleration_helix(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-7ed984da4fae> in <module>
# ----> 1 acceleration_helix(1)
#
# TypeError: 'VectorAdd' object is not callable

# %% [markdown]
# <span style="color:red">**EXERCICIO** Resolva o problema acima definindo uma função para velocidade e aceleração. </span>

# %% [markdown]
# ### Reparametrização

# %% [markdown]
# Como já foi mencionado, a parametrização de uma curva não é única, ou seja, uma curva pode ser representada por parametrizações diferentes. Mas para as curvas que não se interceptam sempre há um jeito para transformar uma parametrização a outra. Esse procedimento se chama reparametrização.  Este é possível através do uso da regra da cadeia. </br>
# Suponha que uma curva não-interceptante tem as duas seguintes parametrizações
# $$
# F(t), t \in [a,b] \qquad e \qquad G(u), u \in[c,d].
# $$
# Então existe uma função  $u=\varphi(t)$ tal que $\varphi(a)=c$ e $\varphi(b)=d$. Então temos $G(u)=G(\varphi(t))=F(t)$. Essa relação define a reparametrização da curva original. Se a parametrização for suave, logo $\varphi$ é diferenciável e $\varphi^\prime$ é continua. Então temos
# $$
# F^\prime (t) = G^\prime (\varphi(t)) \varphi^\prime (t)
# $$

# %% [markdown]
# ## Invariantes Geometricas

# %% [markdown]
# #### Parametrização em Relação ao Comprimento de Arco

# %% [markdown]
# Qunado introduzimos o conceitos de curva parametrizada, digamos que o parametro da curva, a principio, não tem nenhum significado fisico. Porem,  se a curva for a trajetoria de um objeto o parametro *t* pode ser interpretada como *tempo*. Nessa forma, variando o parametro podemos calcular onde está a posição do objeto no espaço. Por exemplo, inserindo $t=3$ na equação da curva vamos ter
# $$
# \vec r (3) = x(3) \hat i + y(3) \hat j + z(3) \hat k.$$
# Ou seja, o objeto está no ponto $(x(3),y(3),z(3))$.
# Mas, as vezes, nos precisamos da posição do objeto tendo informação sobre a distancia percorrida a partir do ponto inicial. Por exemplo, a gente quer saber a posição de uma particula que está se deslocando ao longo de uma helice apos percorrer s = 5 metros. Para calcular isso, temos que reparametrizar a curva e usar *deslocamento* como parametro em vez de *tempo*. A gente chama isso de **Parametrização da curva em relação ao comprimento de arco**.

# %% [markdown]
# Agora a gente está pronto para calcular algumas quantidades invariantes de curvas. Vamos começar por o comprimento de arco.

# %% [markdown]
# ### Comprimento de Arco

# %% [markdown]
# Nós definimos o comprimento de arco como a integral da rapidez. Mais precisamente, o comprimento na curva $\vec r (t)$ entre $t = a$ e $t = b$ é
# $$
# L = \int_a^b v(t) dt = \int_a^b |\vec v (t)| dt.
# $$
# Como a velocidade é não-negativa, a função comprimento de arco
# $$
# s(t) = \int_a^t v(u) du
# $$
# é sempre crescente. Usando o teorema fundamental de calculo podemos calcular a derivada desta função por
# $$
# \frac{ds}{dt} = v(t) = |\vec v (t)| = |\vec{r^\prime}(t)|.
# $$
# Agora vamos verificar que o comprimento de arco é independente da parametrização
# $$
# \int_c^d|G^\prime (u)|du = \int_a^b |G^\prime (\varphi(t))|\varphi^\prime (t) dt = \int_a^b |F^\prime (t)|dt.
# $$
# No caso de uma curva espacial temos
# $$
# \vec r (t) = \left< x(t),y(t),z(t)\right>, \quad t \in R.
# $$
# Neste caso, para calcular o comprimento de arco temos
# $$
# L = \int ds = \int_a^b \frac{ds}{dt} = \int_a^b |\vec{r^\prime}(t)|dt = \int_a^b \sqrt{(x^\prime)^2+(y^\prime)^2+(z^\prime)^2}
# $$

# %% [markdown]
# Para encontrar o comprimento de uma curva entre dois pontos, $t \in [a,b]$ definimos a seguinte função

# %%
def Arc_Length(curve, a:Tuple): 
    return integrate(Norm(curve.diff()),a)

# %%
Arc_Length(helix(t),(t,0,pi))
# Out:
# √2⋅π

# %% [markdown]
# Calculando o valor numérico da expressão acima

# %%
N(Arc_Length(helix(t),(t,0,pi)))

# %% [markdown]
# Calculando a circumferencia de um circulo com raio 3.

# %%
Arc_Length(3*circle(t),(t,0,2*pi))

# %% [markdown]
# <span style="color:red"> **Exercício:** Use a função interna *magnitude()* para calcular o comprimento de uma curva </span>

# %% [markdown]
# #### Parametrização em Relação ao Comprimento de Arco

# %% [markdown]
# Qunado introduzimos o conceitos de curva parametrizada, digamos que o parametro da curva, a principio, não tem nenhum significado fisico. Porem,  se a curva for a trajetoria de um objeto o parametro *t* pode ser interpretada como *tempo*. Nessa forma, variando o parametro podemos calcular onde está a posição do objeto no espaço. Por exemplo, inserindo $t=3$ na equação da curva vamos ter
# $$
# \vec r (3) = x(3) \hat i + y(3) \hat j + z(3) \hat k.$$
# Ou seja, o objeto está no ponto $(x(3),y(3),z(3))$.
# Mas, as vezes, nos precisamos da posição do objeto tendo informação sobre a distancia percorrida a partir do ponto inicial. Por exemplo, a gente quer saber a posição de uma particula que está se deslocando ao longo de uma helice apos percorrer s = 5 metros. Para calcular isso, temos que reparametrizar a curva e usar *deslocamento* como parametro em vez de *tempo*. A gente chama isso de **Parametrização da curva em relação ao comprimento de arco**. O caminho é o seguinte, primerio calcularmos a função de comprimento de arco
# $$
# s(t) = \int_a^t v(u) du.
# $$
# Assim temos uma relação entre $s$ e $t$, ou seja $s = s(t)$. Aí, basta inverter essa relação e escrever $t=s^{-1}(s)$. No final, substituimos esse $t$ na equação da curva.

# %% [markdown]
# Agora podemos verificar que o comprimento da helice é independente da parametrização

# %% [markdown]
# Exemplo: Reparametrizar a helice em relação ao comprimento de arco, começando do ponto $t=0$

# %%
rapidez = Norm(helix(t).diff());
rapidez

# %%
def s(t): return integrate(rapidez,(u,0,t));

# %%
S, s = symbols('S s')

# %%
S = Eq(s, integrate(rapidez,(u,0,t)))

# %%
S

# %%
t = solve(S,t)

# %%
helix(t[0])

# %%
helix(s)

# %% [markdown]
# Preste atencão que a variavel $t$ não é mais independente! Para reutilizar dessa variavel tem que a recriar de novo.

# %%
t

# %%
t = symbols('t')

# %%
t

# %% [markdown]
# ### Triedro de Frenet

# %% [markdown]
# É um conjunto abstrato de três vetores
# $$(\vec T, \vec N , \vec B)$$
# que diz respeito a propriedades cinemáticas de uma partícula que se move em uma trajetória curvilínea, usado em cálculo vetorial. No triedro, o vetor $\vec T$ representa a tangente à curva, o vetor $\vec N$ é a derivada do vetor $\vec T$, e o vetor $\vec B$ é o produto vetorial de $\vec T$ e $\vec N$

# %% [markdown]
# Tendo a equação parametrica de curva $$\vec r (t) = x(t) \hat i +y(t) \hat j+z(t) \hat k,$$ o **vetor tangente unitario** é definido como
# $$
# \vec T(t) = \frac{\frac{d \vec r (t)}{dt}}{|\vec r (t)|} = \frac{\vec{r^\prime}(t)}{|\vec r (t)|}.
# $$
# e o **vetor normal unitário** é
# $$
# \vec N(t) = \frac{\frac{d \vec T (t)}{dt}}{|\vec T (t)|} = \frac{\vec{T^\prime}(t)}{|\vec T (t)|}.
# $$
# Finalmente o **vetor binormal** é definido como o produto vetorial dos vetores $\vec T$ e $\vec N$,
# $$
# \vec B (t) = \vec T (t) \times \vec N (t)
# $$

# %% [markdown]
# ### Curvatura e Torção

# %% [markdown]
# A curvatura mede, em qualquer ponto, o quanto a curva está se dobrando quanto estamos andando ao longo da curva. Dito de outra forma, mede a falha da curva em ser linear. </br>
# Podemos considerar a curvatura como a taxa de variação do vetor tangente em relação ao comprimento de arco. No caso de reta, como o vetor tangente é constante, a curvatura é zero. TEm três formulas equivalentes para calcular a curvatura.
# $$
# \kappa (t) = \left| \frac{d \vec T (t)}{ds}\right| = \frac{\left| \vec{T^\prime}(t)\right|}{\left| \vec{r^\prime}(t)\right|} = \frac{\left|\vec{r^\prime}\times \vec{r^{\prime\prime}}\right|}{\left| \vec{r^\prime}\right|^3}
# $$

# %% [markdown]
# A torção mede o quanto a curva está torcendo ou a falha da curva é planar. Ou seja, a taxa de rotação do vetor binormal. A torção é determinada unicamente pela equação
# $$
# \vec {B^\prime}(t) = \tau(t) \left| \vec{r^\prime}\right| \vec N(t).
# $$
# Prestam atenção que essa equação é composta de três equações. Por exemplo, para o componente $x$ temos
# $$
# B^\prime_x(t) = \tau(t) \left| \vec{r^\prime}\right|  N_x(t).
# $$
# Para achar a torção basta resolver uma dessas três equações.  Tem outra formula para calcular a torção [Wikipedia]
# $$
# \tau (t)=\frac{(\vec{r^\prime}\times \vec{r^{\prime\prime}})\cdot \vec{r^{\prime\prime\prime}} }{\left| \vec{r^\prime} \times \vec{r^{\prime\prime}}\right|}.
# $$

# %% [markdown]
# <span style="color:red"> **EXERCICIO**: Monte uma função para calcular curvatura e torção, pegando a equação da curva como entrada. </span>

# %% [markdown]
# ### Exemplos

# %% [markdown]
# Nessa subseção vamos analisar algumas caracteristicas geometricas de algumas curvas reconhecidas.

# %% [markdown]
# #### Astroide

# %% [markdown]
# Astroide é uma curva bidimensional definida por
# $$
# \vec r (t) = a\cos^3(t) \hat i + a \sin^3(t)\hat j
# $$
# Então uma astroide de raio 2 é implementada na seguinte forma

# %%
def astroid(t, a=2): return a*(cos(t))**3*R.i + a*(sin(t))**3*R.j

# %%
astroid(pi)
# Out:
# (-2)*R.i

# %% [markdown]
# Agora vamos plotar essa curva. Para facilitar a vida vamos montar uma função que que pega uma curva e um intervalo como entrada e gera a plotagem usando *matplotlib*

# %%
def Plot_Parametric_Curve_mat(curve,interval,precision=0.1):
    curve_components = tuple(curve.components.values())
    curve_np = lambdify(t,curve_components)
    points = curve_np(np.arange(interval[0], interval[1], precision));
    
   
    fig, ax = plt.subplots(ncols=1)

    plt.plot(points[0],points[1])

    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title(f'{curve}')
    plt.grid()
    plt.show()

# %%
Plot_Parametric_Curve_mat(astroid(t),(0,2*np.pi))

# %% [markdown]
# Bom, se essa curva foi trajetoria de um objeto qual seria a sua velocidade e aceleração?

# %%
velocity_astroid = astroid(t).diff(t);
velocity_astroid
# Out:
# (-6*sin(t)*cos(t)**2)*R.i + (6*sin(t)**2*cos(t))*R.j

# %%
aceleration_astroid = velocity_astroid.diff();
aceleration_astroid.trigsimp()
# Out:
# (-18*cos(t)**3 + 12*cos(t))*R.i + (-18*sin(t)**3 + 12*sin(t))*R.j

# %% [markdown]
# Para calcular a velocidade e a aceleração da particula em um instante espicifico de tempo podemos usar do *subs*. Por exemplo, vamos ver qual é a velocidade e a aceleração to tempo $t = \frac{\pi}{4}$

# %%
velocity_astroid.subs(t,pi/4)

# %%
aceleration_astroid.subs(t,pi/4)

# %% [markdown]
# Qual é a rapidez desse objeto?

# %%
Norm(velocity_astroid).simplify()
# Out:
# 3⋅│sin(2⋅t)│

# %% [markdown]
# <span style="color:red"> **EXERCICIO** onde a velocidade do objeto fica zero? Faça um grafico da função de rapidez para ter uma ideia. </span>

# %% [markdown]
# O proximo passo será calcular o triedro de Frenet para essa curva. Vamos definir algumas funções para fazer isso

# %%
def UT(curve): return curve.diff()/Norm(curve.diff())

# %%
UT(astroid(t)).simplify()
# Out:
# (-2*sin(t)*cos(t)**2/Abs(sin(2*t)))*R.i + (2*sin(t)**2*cos(t)/Abs(sin(2*t)))*R.j

# %%
def UN(curve): return UT(curve).diff()/Norm(UT(curve).diff())

# %%
UN(astroid(t)).simplify()
# Out:
# (16*(sin(2*t)/2 - 3*sin(4*t)/4 + cos(2*t)*Abs(sin(2*t))*sign(sin(2*t)))/(sqrt(1/(sin(t)**6*cos(t)**6))*sqrt((2*sin(2*t) - 3*sin(4*t) + 4*cos(2*t)*Abs(sin(2*t))*sign(sin(2*t)))**2*cos(t)**2 + (2*sin(2*t) + 3*sin(4*t) - 4*cos(2*t)*Abs(sin(2*t))*sign(sin(2*t)))**2*sin(t)**2)*sin(t)*sin(2*t)**2))*R.i + (16*(sin(2*t)/2 + 3*sin(4*t)/4 - cos(2*t)*Abs(sin(2*t))*sign(sin(2*t)))/(sqrt(1/(sin(t)**6*cos(t)**6))*sqrt((2*sin(2*t) - 3*sin(4*t) + 4*cos(2*t)*Abs(sin(2*t))*sign(sin(2*t)))**2*cos(t)**2 + (2*sin(2*t) + 3*sin(4*t) - 4*cos(2*t)*Abs(sin(2*t))*sign(sin(2*t)))**2*sin(t)**2)*sin(2*t)**2*cos(t)))*R.j

# %%
def UB(curve): return (UT(curve)^UN(curve)).simplify()

# %%
UB(astroid(t)).trigsimp()
# Out:
# (-128*sin(t)**2*cos(t)**2/(sqrt(1/(sin(t)**6*cos(t)**6))*sqrt((2*sin(2*t) - 3*sin(4*t) + 4*cos(2*t)*Abs(sin(2*t))*sign(sin(2*t)))**2*cos(t)**2 + (2*sin(2*t) + 3*sin(4*t) - 4*cos(2*t)*Abs(sin(2*t))*sign(sin(2*t)))**2*sin(t)**2)*Abs(cos(4*t) - 1)*Abs(sin(2*t))))*R.k

# %% [markdown]
# E finalmente vamos calcular a curvatura e torção

# %%
def curvature(curve): return Norm(UT(curve).diff())/Norm(curve.diff())

# %%
curvature(astroid(t)).simplify()
# Out:
#      _________________    ____________________________________________________
#     ╱        1           ╱
#    ╱  ─────────────── ⋅╲╱  (2⋅sin(2⋅t) - 3⋅sin(4⋅t) + 4⋅cos(2⋅t)⋅│sin(2⋅t)│⋅si
#   ╱      6       6
# ╲╱    sin (t)⋅cos (t)
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#              2    2
# gn(sin(2⋅t))) ⋅cos (t) + (2⋅sin(2⋅t) + 3⋅sin(4⋅t) - 4⋅cos(2⋅t)⋅│sin(2⋅t)│⋅sign
#
#
# ──────────────────────────────────────────────────────────────────────────────
#           48
#
# _____________________
#            2    2
# (sin(2⋅t))) ⋅sin (t)
#
#
# ─────────────────────

# %% [markdown]
# Só por curiosidade vamos ver quanto é a curvatura da astroide no ponto $t=\frac{\pi}{4}$

# %%
curvature(astroid(t)).subs(t,pi/4)

# %% [markdown]
# Calcular a torção é um pouco mais complicado. Temos que resolver um sistema linear

# %%
tau = symbols('tau')

# %%
def torsion(curve): return (curve.diff().cross(curve.diff(t,2))).dot(curve.diff(t,3))/Norm(curve.diff().cross(curve.diff(t,2)))

# %%
torsion(astroid(t))

# %% [markdown]
# Podemos definir outra função para calcular a torção utilizando a segunda formula

# %%
def torsion1(curve): return solve(UB(curve.diff()).dot(R.i)+tau * Norm(curve.diff())*UN(curve).dot(R.i),tau)

# %%
torsion1(astroid(t))

# %% [markdown]
# A resposta Zero está entendivel pois a curva é planar e por isso não tem torsão, só tem curvatura.

# %% [markdown]
# #### Cicloide

# %% [markdown]
# a cicloide é uma curva plana definida via (um circoid de raio 2)

# %%
def cicloid(t, r=2): return r*(t-sin(t))*R.i + r*(1-cos(t))*R.j;
cicloid(t)

# %% [markdown]
# Agora vamos dar uma olhada no grafico dessa curva

# %%
Plot_Parametric_Curve_mat(cicloid(t),(0,4*np.pi))

# %% [markdown]
# <span style="color:red"> **EXERCICIO** Faça o mesmo analise que fizemos anteriormente para a cicloide </span>

# %% [markdown]
# #### Epiciclóide

# %%
from IPython.display import display, Image
with open('Epicycloid.gif','rb') as file:
    display(Image(file.read()))

# %% [markdown]
# A curva vermelha é um epiciclóide traçado à medida que o pequeno círculo (raio $r = 1$) rola ao redor do exterior do círculo grande (raio $R = 3$).

# %% [markdown]
# Um epiciclóide pode ser implementado como (de raio marior R=3 e raio menor r=1)

# %%
def epicycloid(t, Rad=3, r=1): return ((Rad+r)*cos(t)-r*cos(t*(r+Rad)/r))*R.i + ((Rad+r)*sin(t)-r*sin(t*(r+Rad)/r))*R.j ;
epicycloid(t)

# %%
Plot_Parametric_Curve_mat(epicycloid(t),(0,4*np.pi))

# %% [markdown]
# #### Epitrocóide

# %%
from IPython.display import display, Image
with open('Epitrochoid.gif','rb') as file:
    display(Image(file.read()))

# %% [markdown]
# The epitrochoid com R = 3, r = 1 e d = 1/2

# %%
def epitrochoid(t, Rad=3, r=1, d=0.5): return ((Rad+r)*cos(t)-d*cos(t*(r+Rad)/r))*R.i + ((Rad+r)*sin(t)-d*sin(t*(r+Rad)/r))*R.j ;
epitrochoid(t)

# %%
Plot_Parametric_Curve_mat(epitrochoid(t),(0,4*np.pi))

# %% [markdown]
# <span style="color:red"> **EXERCICIO** Faça o mesmo analise que fizemos anteriormente para as curvas epitrocoide e epicicloide </span>

# %% [markdown]
# #### Cubica Retorcida

# %% [markdown]
# Essa curva é definida como

# %%
def cubic(t): return t*R.i + (t**2)*R.j + (t**3)*R.k;
cubic(t)

# %% [markdown]
# Agora vamos plotar essa curva utilizando Sympy

# %%
Plot3d_Parametric_Curve(cubic(t),(t,0,2*pi))

# %% [markdown]
# Já que temos funções definidas para triedro de Frenet é facil achar-las para essa curva é

# %%
UT(cubic(t))

# %%
UN(cubic(t)).simplify()

# %%
UB(cubic(t))

# %% [markdown]
# A curvatura e torsão dessa curva são

# %%
curvature(cubic(t))

# %%
torsion(cubic(t))

# %% [markdown]
# <span style="color:red"> **EXERCICIO** encontra os vetores tangente, normal e binormal no ponto $t=\frac{\pi}{4}$. Calcule a curvatura e torsão nos pontos $t=\frac{\pi}{4}, \frac{\pi}{2}, \pi$ </span>

# %% [markdown]
# ## Planos Tangentes

# %% [markdown]
# ### Definição

# %% [markdown]
# Antes de falar sobre os planos tangentes vamos recordar alguns detalhes sobre os planos no sistema de coordenadas cartesianas.
# Um plano pode ser construido em varias formas tais como
# * Um ponto e vetor normal ao plano
# * Um ponto e dois vetores não-paralelos contidos no plano.
# **Na primeira forma**, temos um ponto $X_0(x_0,y_0,z_0)$ e um vetor normal(ortoginal, perpendicular) $\vec n=(a,b,c)$. A equação geral do plano é dado por
# $$
# a(x-x_0) + b(y-y_0) + c(z-z_0) = 0 \rightarrow ax+by+cz=d
# $$
# **Na segunda forma** temos um ponto $X_0(x_0,y_0,z_0)$  e dois vetores $\vec a=(a_1,a_2,a_3)$ e  $\vec b=(b_1,b_2,b_3)$. A equação paramétrica do plano é dado por
# $$
# \vec r (s,t) = \begin{cases}
# x = x_0 + a_1 t + b_1 s
# \\ y = y_0 + a_2 t + b_2 s
# \\ z = z_0 + a_3 t + b_3 s
# \end{cases}
# $$
# Apesar que a primeira expressão é muito mais simples a segunda forma de construir um plano muitas vezes é mais conveniente e esclarecedor.
# A primeira forma pode ser esboçado com o comando *plat3d* (escrevendo na forma $z=f(x)$) mas para desenhar o segundo precisamos usar *plot3d_parametric_surface* pois estamos tratando com uma expressão paramétrica.
# Por exemplo, se tivemos $z = 3x - y$ podemos o desenhar com

# %%
plot3d(3*x-y, (x,-2,2),(y,-2,2))

# %% [markdown]
# E se tivemos dois vetores $(2,3,5)$ e $(-7,-11,13)$ e quisemos plotar um plano que seja paralelo aos esses vetores que passa pelo o ponto $(17, 29, 0)$ teremos a seguinte equação paramétrica
# $$
# \vec r (s,t) = (19,29,0) + t(2,3,5) + s (-7,-11,13)
# $$
# ou
# $$
# \vec r (s,t) = (17+2t-7s)\hat i + (29+3t-11s)\hat j + (5t+13s)\hat k.
# $$
# E para desenhar

# %%
plot3d_parametric_surface(17+2*t-7*s,29+3*t-11*s,5*t+13*t,(t,-1,1),(s,-1,1))

# %% [markdown]
# ### Plotar um plano

# %% [markdown]
# Para facilitar a vida, vamos construir uma função que pega tres pontos no espaço e devolva o plano que passa pelo esses tres pontos (no formato $z = f(x)$).

# %% [markdown]
# #### Plotar um plano usando Sympy

# %% [markdown]
# Da fato, exite essa função no Sympy mas o resultado imediato não serve para plotar! Então, a gente vai definir uma função nova utilizando o resultado dessa função e transformando em algo "plotavel"!

# %%
def plane(a,b,c): 
    global x
    global y
    global z
    x, y , z = symbols("x y z")
    plane_temp = Plane(Point3D(*a),Point3D(*b),Point3D(*c))
    vn = plane_temp.normal_vector;
    
    return -(vn[0]*(x-a[0])+vn[1]*(y-a[1]))/vn[2] + a[2]

# %%
plane1 = plane((2,3,4),(5,6,7),(8,3,2));
plane1
# Out:
#   x   4⋅y   2
# - ─ + ─── + ─
#   3    3    3

# %% [markdown]
# Outra forma de definir essa função é definir o seguinte determinante
# $$
# A =\left[ {\begin{array}{ccccc}
# x & y & z & 1 \\
# x_1 & y_1 & z_1 & 1 \\
# x_2 & y_2 & z_2 & 1 \\
# x_3 & y_3 & z_3 & 1 \\
# \end{array} } \right],
# $$
# e resolver a equação  $A =0$. [Equation of a plane passing through 3 points](https://math.stackexchange.com/questions/2686606/equation-of-a-plane-passing-through-3-points)

# %%
def plane(a,b,c): 
    global x
    global y
    global z
    x, y , z = symbols("x y z")
      
    matrix = [[x ,y, z,1],[a[0],a[1],a[2],1],
                      [b[0],b[1],b[2],1],[c[0],c[1],c[2],1]]
    matrix = Matrix(matrix)
    return solve(matrix.det(),z)[0]

# %%
plane2 = plane((2,3,4),(5,6,7),(8,3,2));
plane2
# Out:
#   x   4⋅y   2
# - ─ + ─── + ─
#   3    3    3

# %%
plane2.subs(x,2)
# Out:
# 4⋅y
# ───
#  3

# %% [markdown]
# Agora sim, conseguimos plotar utilizando a função de plotagem interna do Sympy

# %%
plot3d(plane2,(x,-2,2),(y,-2,2))

# %% [markdown]
# #### Plotar um plano usando matplotlib

# %% [markdown]
# Para ter mais informação sobre a função abaixo dão uma olhada na pagina [mplot3d tutorial](https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html)

# %%
def plot3d_mat(surface, interx, intery , precision = 0.01):
    
    from mpl_toolkits.mplot3d import Axes3D
    from matplotlib import cm

    fig = plt.figure()
    ax = fig.gca(projection='3d')
    #ax = plt.subplot(projection='3d')
    
    points_x = np.arange(interx[1],interx[2],precision)
    points_y = np.arange(intery[1],intery[2],precision)
    
    points_x, points_y = np.meshgrid(points_x, points_y)
    
    points_z = lambdify([interx[0],intery[0]],surface)
    
    surf = ax.plot_surface(points_x,points_y,
                    points_z(points_x,points_y),cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
    
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    plt.title(surface)
    plt.tight_layout()
    fig.colorbar(surf, shrink=0.5, aspect=5)
    #plt.grid()

# %%
plot3d_mat(plane2,(x,-2,2),(y,-2,2))

# %% [markdown]
# ### Usar derivadas parciais para achar plano tangente

# %% [markdown]
# Agora vamos para o assunto principal, plano tangente. Como vimos no caso de curva, em cada ponto da curva existe um vetor tangente a curva. Generalizando esse conceito para superficies, estudamos a existência de um plano tangente em cada ponto da superfície.
# Em cada ponto de uma superfície passam infinitas curvas. Duas dessas curvas são mais interessantes para a gente: a curva de interseção da superfície com o plano $y=y_0$ e a curva de interseção com o plano $x=x_0$. É melhor estudar via um exemplo.
# Consideram a superfície
# $$
# z = x^2 + 3xy + y^2
# $$
# Vamos achar o plano tangente a essa superfície no ponto $(1,-2,-1)$. Primeiro a definimos e depois esboçamos ela

# %%
def z(x,y): return x**2+3*x*y + y**2

# %%
plot3d(z(x,y), (x,-2,2),(y,-3,1))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# E os planos $x = 1$ e $y = -2$ podem ser construidos por três pontos do plano na seguinte forma

# %%
planex = plane((1,1,1),(1,0,0),(1,0,1));
planex
# Out:
# zoo⋅(x - 1) + 1

# %%
planoy = plane((0,-2,0),(1,-2,0),(0,-2,1));
planoy
# Out:
# zoo⋅(y + 2)

# %% [markdown]
# Aparentemente as nossas funções não conseguem construir esse tipo de plano. Faz sentido; pois não tem uma equação na forma $z = f(x,y)$. Mas ainda tem como construir esse planos usando a função interna do Sympy, por exemplo, para $x=1$ temos

# %%
plx = Plane(Point3D(1,1,1),Point3D(1,0,0),Point3D(1,0,1));
plx
# Out:
# Plane(Point3D(1, 1, 1), (-1, 0, 0))

# %%
plx.normal_vector
# Out:
# (-1, 0, 0)

# %% [markdown]
# O objeto construido dessa forma tem um atributo *equation* para gerar a equação do plano no formato $f(x,y,z)=0$

# %%
plx.equation()
# Out:
# 1 - x

# %% [markdown]
# Mas como podemos plotar esses plano?! Para usar a função *plot3d* precisamos uma equação na fomra $z = f(x,y)$O caminho mais simples é utilizar o *matplotlib*

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

yy, zz = np.meshgrid(range(-2,2), range(-2,2))
xx = np.ones((4,4))

ax = plt.subplot(projection='3d')

# o plano x=1
ax.plot_surface(xx, 2*yy, zz)

# o plano y=-2
ax.plot_surface(2*yy,-2*xx,zz)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

yy, zz = np.meshgrid(np.arange(-2,2,0.01), np.arange(-2,2,0.01))
xx = np.ones(yy.shape)

ax = plt.subplot(projection='3d')

# o plano x=1
ax.plot_surface(xx, 2*yy, zz)

# o plano y=-2
ax.plot_surface(2*yy,-2*xx,zz)

ax.plot_surface(yy,zz,1/5*z(yy,zz))
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
z(x,y)
# Out:
#  2            2
# x  + 3⋅x⋅y + y

# %%
pointsz.shape
# Out:
# (1000, 1000)

# %%
plot3d(,(y,-5,5),(z,-5,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-220-0e673d2a915b> in <module>
# ----> 1 plot3d(Eq(x,1),(y,-5,5),(z,-5,5))
#
# ~/miniconda3/lib/python3.7/site-packages/sympy/plotting/plot.py in plot3d(*args, **kwargs)
#    1948     plots = Plot(*series, **kwargs)
#    1949     if show:
# -> 1950         plots.show()
#    1951     return plots
#    1952
#
# ~/miniconda3/lib/python3.7/site-packages/sympy/plotting/plot.py in show(self)
#     189             self._backend.close()
#     190         self._backend = self.backend(self)
# --> 191         self._backend.show()
#     192
#     193     def save(self, path):
#
# ~/miniconda3/lib/python3.7/site-packages/sympy/plotting/plot.py in show(self)
#    1246
#    1247     def show(self):
# -> 1248         self.process_series()
#    1249         #TODO after fixing https://github.com/ipython/ipython/issues/1255
# ...

# %%
[x in planex.atoms() for x in [zoo,oo]]
# Out:
# [True, False]

# %%
# Out:
# {-1, 1, zoo, x}

# %% [markdown]
# ## Superficies Parametrizadas

# %% [markdown]
# Antes de tudo, precisamos definir uma função que crie uma superfície parametrizada. Como sabemos, uma superfície parametrizada tem dois parâmetros.

# %%
def surface1(u,v): return v*cos(u)*R.i + v*sin(u)*R.j + v*R.k

# %%
surface1(u,v)

# %% [markdown]
# Now we have learnt how to plot a curve, we can plot a surface easily but using the module *plot3d_parametric_surface*. We again go throught the procedure first and then construct a function for it

# %%
surface_components = tuple(surface1(u,v).components.values())

# %%
surface_components

# %%
plot3d_parametric_surface(*surface_components, (u,0,5*pi),(v,0,5*pi))
plt.show()

# %% [markdown]
# another surface

# %%
def surface2(u,v): return v*cos(u)*R.i + v*sin(u)*R.j + u*R.k

# %%
plot3d_parametric_surface(*tuple(surface2(u,v).components.values()), (u,0,5*pi),(v,0,5*pi))
plt.show()

# %% [markdown]
# Let's plot a unit sphere. First we have to define it in a parametrized way

# %%
def sphere(phi, theta): return sin(phi)*cos(theta)*R.i + sin(phi)*sin(theta)*R.j + cos(phi)*R.k

# %%
plot3d_parametric_surface(*tuple(sphere(phi,theta).components.values()), (phi,0,pi),(theta,0,2*pi))
plt.show()

# %% [markdown]
# If the above plot has some problem and is not a perfect sphere, we need to modify some internal functionality of *matplotlib* to solve this issue. A blessed guy helped me find a solution for it [Plot a perfect sphere with equal axes by parametric plot in Sympy](https://stackoverflow.com/questions/60332066/plot-a-perfect-sphere-with-equal-axes-by-parametric-plot-in-sympy)

# %%
plt.rcParams['figure.figsize'] = 6, 5.6
plot3d_parametric_surface(*tuple(sphere(phi,theta).components.values()), (phi,0,pi),(theta,0,2*pi))
plt.show()

# %% [markdown]
# We can calculate the derivative of a parametrized surface with respect to its parameters

# %%
surface1(u,v).diff(v)

# %%
surface1(u,v).diff(u)

# %% [markdown]
# It would be nice to have a function that gives us the area of a parametrized surface

# %%
def Surface_Area(surface, a,b):
    '''
        This function calculate the area of a 3D parametrized surface
        surface:(Tuple) parametrized surface
        a:(Tuple) (first parameter of the surface, initial point, final point)
        b:(Tuple) (second parameter of the surface, initial point, final point)
    '''
        
    module = Norm(surface.diff(a[0])^surface.diff(b[0]))
    return integrate(module, a ,b)

# %% [markdown]
# For example the area of a sphere with radius 2 is

# %%
Surface_Area(2*sphere(phi,theta), (theta,0,2*pi), (phi,0,pi))

# %% [markdown]
# As the parametrized curves, we can imagine the parametrized surfaces are infinite points drawn by a vector originated from center of the coordinate system. By varying two parameters of a surface equation we can access to its different points.

# %%
Plot3d_Position_Vector(sphere(theta,phi), (phi, 0, pi), (theta,0, pi))

# %% [markdown]
# ## Vectorial Fields

# %%
def field1(x,y,z): return x**2*R.i + y**2*R.j + z**2*R.k

# %%
field1(x,y,z)

# %% [markdown]
# The associated vector to a point in the space can be yielded by

# %%
field1(2,2,2)

# %%
def field2(x,y): return x**2*R.i + y**2*R.j

# %%
field2(x,y)

# %% [markdown]
# Plotting a 2D vector field

# %%
helix_norm = Norm(helix(t));
helix_norm

# %%
def Plot_Vector_Field(field, a, b):
    import matplotlib.pyplot as plt
    import numpy as np
    # %matplotlib inline
    
    f = tuple(field.components.values())
    
    assert len(a)==len(b)==3 , "A 2D vector field need two inputs (as Tuple), each one with three elements "
    assert len(f)==2, "This function just handle 2D vector fields"
    
    xrange = np.linspace(a[1],a[2],15)
    yrange = np.linspace(b[1],b[2],15)
    X,Y = np.meshgrid(xrange, yrange)

    U= np.zeros((15,15))
    V= np.zeros((15,15))

    for i in range(len(xrange)):
        for j in range(len(yrange)):
            x1 = X[i,j]
            y1 = Y[i,j]
            U[i,j] = f[0].subs({a[0]:x1, b[0]:y1})
            V[i,j] = f[1].subs({a[0]:x1, b[0]:y1})

    plt.quiver(X,Y,U,V)
    plt.title(f"vector field {f}")
    plt.show()

# %% [markdown]
# Checking the above function

# %%
Plot_Vector_Field(field2(x,y),(x,-3,3),(y,-3,3))

# %% [markdown]
# Plotting a 3D vector field **this function needs some adjusments**

# %%
def Plot3d_Vector_Field(field, a, b, c, mesh_size=10, length=None):
    
    f = tuple(field.components.values())
    assert len(a)==len(b)==len(c)==3, "A 3D vector field needs three argments"
    assert len(f)==3, "This function just handle the 3D vector fields"
    
    from mpl_toolkits.mplot3d import axes3d
    import matplotlib.pyplot as plt
    import numpy as np
    # %matplotlib inline    
    
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

# Make the grid
    xrange = np.linspace(a[1],a[2],mesh_size)
    yrange = np.linspace(b[1],b[2],mesh_size)
    zrange = np.linspace(c[1],c[2],mesh_size)
    x, y, z = np.meshgrid(xrange, yrange, zrange)
    

# Make the direction data for the arrows
    u = np.zeros((mesh_size,mesh_size,mesh_size))
    v = np.zeros((mesh_size,mesh_size,mesh_size))
    w = np.zeros((mesh_size,mesh_size,mesh_size))
    
    for i in range(len(xrange)):
        for j in range(len(yrange)):
            for k in range(len(zrange)):
                x1 = x[i,j,k]
                y1 = y[i,j,k]
                z1 = z[i,j,k]
                u[i,j,k] = f[0].subs({a[0]:x1, b[0]:y1, c[0]:z1})
                v[i,j,k] = f[1].subs({a[0]:x1, b[0]:y1, c[0]:z1})
                w[i,j,k] = f[2].subs({a[0]:x1, b[0]:y1, c[0]:z1})

    ax.quiver(x, y, z, u, v, w, length=length, normalize=True)

    plt.show()

# %% [markdown]
# Checking the above function

# %%
Plot3d_Vector_Field(field1(x,y,z), (x,-10,10),(y,-10,10),(z,-10,20),length=0.5)

# %% [markdown]
# A better plooting function for 3D vector fields. This function needs Mayavi package

# %%
def Plot3d_Vector_Field_mayavi(field, a, b, c, mask_points=5, scale_factor=3, mesh_size=10):
    
    f = tuple(field.components.values())
    assert len(a)==len(b)==len(c)==3, "A 3D vector field needs three argments"
    assert len(f)==3, "This function just handle the 3D vector fields"
    
    # %gui qt
    import numpy as np
    from mayavi import mlab   
    mlab.init_notebook()
    mlab.clf()
    
# Make the grid
    xrange = np.linspace(a[1],a[2],mesh_size)
    yrange = np.linspace(b[1],b[2],mesh_size)
    zrange = np.linspace(c[1],c[2],mesh_size)
    x, y, z = np.meshgrid(xrange, yrange, zrange)
    

# Make the direction data for the arrows
    u = np.zeros((mesh_size,mesh_size,mesh_size))
    v = np.zeros((mesh_size,mesh_size,mesh_size))
    w = np.zeros((mesh_size,mesh_size,mesh_size))
    
    for i in range(len(xrange)):
        for j in range(len(yrange)):
            for k in range(len(zrange)):
                x1 = x[i,j,k]
                y1 = y[i,j,k]
                z1 = z[i,j,k]
                u[i,j,k] = f[0].subs({a[0]:x1, b[0]:y1, c[0]:z1})
                v[i,j,k] = f[1].subs({a[0]:x1, b[0]:y1, c[0]:z1})
                w[i,j,k] = f[2].subs({a[0]:x1, b[0]:y1, c[0]:z1})

    src = mlab.pipeline.vector_field(u, v, w)
    return mlab.pipeline.vectors(src, mask_points=mask_points, scale_factor=scale_factor)

# %% [markdown]
# Checking the above function.

# %%
Plot3d_Vector_Field_mayavi(field1(x,y,z), (x,-10,10),(y,-10,10),(z,-10,20))

# %% [markdown]
# ## Differential Operations

# %% [markdown]
# **Attention! these functions work only for Cartesian Coordinate System**

# %% [markdown]
# Gradient of an scalar function. The result is a vector field

# %%
def Gradient(f,*args):
    assert len(args)>0 , "Insert the variables"
    grad=[]
    for var in args:
        grad.append(diff(f,var))
    if len(grad)==3:
        return grad[0]*R.i + grad[1]*R.j + grad[2]*R.k
    if len(grad)==2:
        return grad[0]*R.i + grad[1]*R.j

# %%
Gradient(x*y*sin(z**2),x,y,z)

# %%
Gradient(x*y*sin(x**2),x,y)

# %% [markdown]
# Curl of a 3D vector field. The result continue as a vector field

# %%
def Curl(field, *args):
    f = tuple(field.components.values())
    assert len(args)==len(f)==3, "This function works just in 3D space"
    return (diff(f[2],args[1])-diff(f[1],args[2]))*R.i + (diff(f[1],args[2])-diff(f[2],args[0]))*R.j \
                + (diff(f[1],args[0])-diff(f[1],args[0]))*R.k

# %% [markdown]
# Checking the above function

# %%
Curl(field1(x,y,z),x,y,z)

# %% [markdown]
# Divergent of a vector field. The result is an scalar function

# %%
def Divergent(field, *args):
    f = tuple(field.components.values())
    assert len(f)==len(args), "The number of components of the vector field must be equal to the number of given variables"
    result=0
    for index,component in enumerate(f):
        result+=diff(component,args[index])
    return result

# %% [markdown]
# Checking the above function

# %%
Divergent(field1(x,y,z),x,y,z)

# %% [markdown]
# ## Line Integral

# %% [markdown]
# Line integrais are frequently encountered in science and engineering $$\int_a^b \vec{F}. d\vec{r}$$

# %%
def Line_Integral(field,curve,a):
    '''
    field: Vector field F(x,y,z) = P(x,y,z)i + R(x,y,z)j + Q(x,y,z)k
    curve: parametrized curve r(t) = x(t)i + y(t)j + z(t)k
    a:(Tuple) (parameter of the curve, initial point, final point)
    Note: if the field is tridimensional, the curve also must have the same dimension. 
    
    '''
    f = tuple(field.components.values())
    c = tuple(curve.components.values())
    assert len(c)==len(f), "Error: Dimensionaluity of the field and the curve must be equal."
    

    coordinate = [x,y,z]
    parametrized_field=[]
    #first we have to parametrize the field using the parametric euqations of curve.
    for index, component in enumerate(f):
        parametrized_field.append(component.subs(coordinate[index],c[index]))
        
    if len(f)==2:
        new_field = parametrized_field[0]*R.i + parametrized_field[1]*R.j 
    if len(f) == 3:    
        new_field = parametrized_field[0]*R.i + parametrized_field[1]*R.j + parametrized_field[2]*R.k 
        
    # new_filed is the parametrized field
    
    integrand = new_field.dot(diff(curve))
    
        
    return integrate(integrand,a)

# %% [markdown]
# For example

# %%
field1(x,y,z)

# %%
helix(t)

# %%
Line_Integral(field1(x,y,z),helix(t), (t,0,pi))

# %% [markdown]
# An example in 2D

# %%
field2(x,y)

# %%
circle(t)

# %%
Line_Integral(field2(x,y),circle(t), (t,0,pi))

# %% [markdown]
# ## Surface integral

# %% [markdown]
# The flux of a vectorial field through a surface is calculated using surface integral

# %%
def Surface_Integral(field,surface, a = 0, b = 0):
    '''
    field:(Tuple) Vector field
    surface:(Tuple) parametrized surface
    a:(Tuple) (first parameter of the surface, initial point, final point)
    b:(Tuple) (second parameter of the surface, initial point, final point)
    Note: if the vector field is tridimensional, the surface also must have the same dimensions. 
    
    '''
    
    f = tuple(field.components.values())
    s = tuple(surface.components.values())
    assert len(f)==len(s), "Error: Dimensionaluity of the field and the curve must be equal."
    
    module = diff(surface,a[0])^diff(surface,b[0])
    #module = Cross(Diff(surface,a[0]),Diff(surface,b[0]))
    
    coordinate = [x,y,z]
    parametrized_field=[]
    #first we have to parmetrize the field using the parametric euqations of curve.
    for index, component in enumerate(f):
        parametrized_field.append(component.subs(coordinate[index],s[index]))
        
    if len(f)==2:
        new_field = parametrized_field[0]*R.i + parametrized_field[1]*R.j 
    if len(f) == 3:    
        new_field = parametrized_field[0]*R.i + parametrized_field[1]*R.j + parametrized_field[2]*R.k 
    
    '''coordinate = [x,y,z]
    parametrized_field=[]
    for index, component in enumerate(field):
        parametrized_field.append(Substitute(component,(coordinate[index], surface[index])))
    '''
    
    return integrate(new_field.dot(module),a,b)

# %% [markdown]
# For example we get

# %%
surface1(u,v)

# %% [markdown]
# The flux of the field $\vec{F}(x,y,z) = x^2 \hat{i} + y^2 \hat{j} + z^2 \hat{k}$ through the
# $$\vec{S}(u,v) = \displaystyle (v \cos{\left(u \right)})\mathbf{\hat{i}_{R}} + (v \sin{\left(u \right)})\mathbf{\hat{j}_{R}} + (v)\mathbf{\hat{k}_{R}}$$
# in the range $u \in [0,\pi]$ and $v \in [0,3]$ is

# %%
Surface_Integral(field1(x,y,z),surface1(u,v), (u,0,pi), (v,0,3))

# %% [markdown]
# The flux of the field $\vec{F}(x,y,z) = x^2 \hat{i} + y^2 \hat{j} + z^2 \hat{k}$ through of a sphere with radious 1 is

# %%
Surface_Integral(field1(x,y,z),sphere(phi,theta), (theta,0,2*pi), (phi,0,pi))
